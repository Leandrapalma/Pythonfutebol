# %% [markdown]
# # Operadores de Comparação

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dois = 2

# %%
#comparação
dois == 2
# Out:
# True

# %%
dois != 2
# Out:
# False

# %%
dois > 1
# Out:
# True

# %%
dois >= 3
# Out:
# False

# %%
dois <= 3
# Out:
# True

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(5 < 7) and (10 < 11)
# Out:
# True

# %%
(3 > 7) and (7 > 11)
# Out:
# False

# %%
(2 < 3) or (10 > 11)
# Out:
# True

# %%
(3 > 5) or (4 > 5)
# Out:
# False

# %%
not (3 < 4)
# Out:
# False

# %%
not (5 > 6)
# Out:
# True

# %% [markdown]
# # Operadores de Associação

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista = [4,5,6,7]

# %%
7 in lista
# Out:
# True

# %%
4 not in lista
# Out:
# False

# %%
8 not in lista
# Out:
# True
